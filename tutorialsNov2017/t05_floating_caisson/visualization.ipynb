# %% [markdown]
# # Visualization

# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
from floating2D import *
from nbtools import plot_domain

plot_domain(domain)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
data = np.genfromtxt('record_rectangle1.csv', delimiter=',', names=True)
fig = plt.figure()
plt.grid()
plt.plot(data['t'], data['y']-data['y'][0], 'r-')
plt.plot(data['t'], data['rotq_e3'], 'b-')
# Out:
# <img src="data:image/png;base64,..." width="640">
